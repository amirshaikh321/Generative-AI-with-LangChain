# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from langchain_core.prompts import PromptTemplate
from langchain_community.vectorstores import FAISS
from langchain_core.output_parsers import StrOutputParser
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
video_id = "Gfr50f6ZBvo" # only the ID, not full URL
try:
    # If you don’t care which language, this returns the “best” one
    transcript_list = YouTubeTranscriptApi.list_transcripts("Gfr50f6ZBvo")

    # Flatten it to plain text
    transcript = " ".join(chunk["text"] for chunk in transcript_list)
    print(transcript)

except TranscriptsDisabled:
    print("No captions available for this video.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 4
#       1 video_id = "Gfr50f6ZBvo" # only the ID, not full URL
#       2 try:
#       3     # If you don’t care which language, this returns the “best” one
# ----> 4     transcript_list = YouTubeTranscriptApi.list_transcripts("Gfr50f6ZBvo")
#       6     # Flatten it to plain text
#       7     transcript = " ".join(chunk["text"] for chunk in transcript_list)
#
# AttributeError: type object 'YouTubeTranscriptApi' has no attribute 'list_transcripts'

# %%
transcript_list = YouTubeTranscriptApi.list_transcripts("5WemQ0")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 transcript_list = YouTubeTranscriptApi.list_transcripts("Gfr50f6ZBvo")
#
# AttributeError: type object 'YouTubeTranscriptApi' has no attribute 'list_transcripts'
